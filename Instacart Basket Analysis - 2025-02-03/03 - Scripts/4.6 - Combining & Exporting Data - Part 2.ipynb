# %% [markdown]
# # Table of Contents

# %% [markdown]
# ### 1. Importing Libraries
# ### 2. Importing Data
# ### 3. Merging Data Frames
# ### 4. Exporting Data

# %% [markdown]
# # 1. Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Importing Data

# %%
# Importing data set orders_combined.pkl

df_ords_combined = pd.read_pickle(r'/Users/xxx/Documents/Instacart Basket Analysis - 2025-01-05/02 - Data/Prepared Data/orders_combined.pkl')

# %%
# Checking the shape

df_ords_combined.shape
# Out:
# (32434489, 12)

# %%
# Shape is the same as exported .pkl

# %%
# Importing data set df_prods_deps.csv

df_prods_deps = pd.read_csv(r'/Users/xxx/Documents/Instacart Basket Analysis - 2025-01-05/02 - Data/Prepared Data/prods_deps_wrangled.csv')

# %%
df_prods_deps
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49688       49688       49684
# 49689       49689       49685
# 49690       49690       49686
# 49691       49691       49687
# 49692       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49688          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
# Specify the columns to include in the new DataFrame
selected_columns = ['product_id', 'product_name', 'aisle_id', 'department_id', 'prices', 'department']

# Create a new DataFrame using the selected columns
df_prods_deps_clean = df_prods_deps[selected_columns]

# Display the new DataFrame to verify its contents (optional)
print(df_prods_deps_clean.head()) # Display the first few rows
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices department
# 0             19     5.8     snacks
# 1             13     9.3     pantry
# 2              7     4.5  beverages
# 3              1    10.5     frozen
# 4             13     4.3     pantry

# %%
df_prods_deps_clean
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices     department
# 0            61             19     5.8         snacks
# ...

# %%
# Export df_prods_deps_clean
df_prods_deps_clean.to_csv(os.path.join('/Users', 'xxx', 'Documents', 'Instacart Basket Analysis - 2025-01-05', '02 - Data','Prepared Data', 'prods_deps_cleaned.csv'))

# %%
# Export df_prods_deps_clean.pkl
df_prods_deps_clean.to_pickle(os.path.join('/Users', 'xxx', 'Documents', 'Instacart Basket Analysis - 2025-01-05', '02 - Data','Prepared Data', 'prods_deps_cleaned.pkl'))

# %%
# Show df_ords_combined
df_ords_combined
# Out:
#             index  order_id  user_id eval_set  order_number  order_weekday  \
# 0               0   2539329        1    prior             1              2
# 1               0   2539329        1    prior             1              2
# 2               0   2539329        1    prior             1              2
# 3               0   2539329        1    prior             1              2
# 4               0   2539329        1    prior             1              2
# ...           ...       ...      ...      ...           ...            ...
# 32434484  3421081   2977660   206209    prior            13              1
# 32434485  3421081   2977660   206209    prior            13              1
# 32434486  3421081   2977660   206209    prior            13              1
# 32434487  3421081   2977660   206209    prior            13              1
# 32434488  3421081   2977660   206209    prior            13              1
#
# ...

# %%
# Show df_prods_deps_clean
df_prods_deps_clean
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices     department
# 0            61             19     5.8         snacks
# ...

# %% [markdown]
# # 3. Merging Data Frames

# %%
# Combine the data frames using the merge function on "product_id"
# df_ords_prods_deps_combined = pd.merge(df_ords_combined, df_prods_deps_clean, on='product_id', how='inner', indicator = True)
# df_ords_prods_deps = df_ords_combined.merge(df_prods_deps_clean, on='product_id', indicator = True)

# Merge the data frames using a custom name for the indicator column
df_ords_prods_deps = df_ords_combined.merge(
df_prods_deps_clean,
on='product_id',
indicator='final_merge_indicator'
)

# Display the first few rows of the resulting data frame
print(df_ords_prods_deps.head())
# Out:
#    index  order_id  user_id eval_set  order_number  order_weekday  order_hour  \
# 0      0   2539329        1    prior             1              2           8
# 1      0   2539329        1    prior             1              2           8
# 2      0   2539329        1    prior             1              2           8
# 3      0   2539329        1    prior             1              2           8
# 4      0   2539329        1    prior             1              2           8
#
#    days_since_last_order  product_id  add_to_cart_order  reordered _merge  \
# 0                      0         196                  1          0   both
# 1                      0       14084                  2          0   both
# 2                      0       12427                  3          0   both
# 3                      0       26088                  4          0   both
# 4                      0       26405                  5          0   both
#
# ...

# %%
# Show df_ords_prods_deps_combined
df_ords_prods_deps
# Out:
#             index  order_id  user_id eval_set  order_number  order_weekday  \
# 0               0   2539329        1    prior             1              2
# 1               0   2539329        1    prior             1              2
# 2               0   2539329        1    prior             1              2
# 3               0   2539329        1    prior             1              2
# 4               0   2539329        1    prior             1              2
# ...           ...       ...      ...      ...           ...            ...
# 32434207  3421081   2977660   206209    prior            13              1
# 32434208  3421081   2977660   206209    prior            13              1
# 32434209  3421081   2977660   206209    prior            13              1
# 32434210  3421081   2977660   206209    prior            13              1
# 32434211  3421081   2977660   206209    prior            13              1
#
# ...

# %%
# Display unique values in the new indicator column
print(df_ords_prods_deps['final_merge_indicator'].unique())
# Out:
# ['both']
# Categories (3, object): ['left_only', 'right_only', 'both']

# %%
# Specify the columns to include in the new DataFrame
selected_columns = ['order_id', 'user_id', 'order_number', 'order_weekday', 'order_hour', 'days_since_last_order', 'product_id', 'add_to_cart_order', 'reordered', 'product_name', 'aisle_id', 'department_id', 'prices', 'department', 'final_merge_indicator']

# Create a new DataFrame using the selected columns
df_ords_prods_deps_clean = df_ords_prods_deps[selected_columns]

# Display the new DataFrame to verify its contents (optional)
print(df_ords_prods_deps_clean.head()) # Display the first few rows
# Out:
#    order_id  user_id  order_number  order_weekday  order_hour  \
# 0   2539329        1             1              2           8
# 1   2539329        1             1              2           8
# 2   2539329        1             1              2           8
# 3   2539329        1             1              2           8
# 4   2539329        1             1              2           8
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                      0         196                  1          0
# 1                      0       14084                  2          0
# 2                      0       12427                  3          0
# 3                      0       26088                  4          0
# 4                      0       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# ...

# %%
# Check df_ords_prods_deps_clean
df_ords_prods_deps_clean
# Out:
#           order_id  user_id  order_number  order_weekday  order_hour  \
# 0          2539329        1             1              2           8
# 1          2539329        1             1              2           8
# 2          2539329        1             1              2           8
# 3          2539329        1             1              2           8
# 4          2539329        1             1              2           8
# ...            ...      ...           ...            ...         ...
# 32434207   2977660   206209            13              1          12
# 32434208   2977660   206209            13              1          12
# 32434209   2977660   206209            13              1          12
# 32434210   2977660   206209            13              1          12
# 32434211   2977660   206209            13              1          12
#
#           days_since_last_order  product_id  add_to_cart_order  reordered  \
# ...

# %% [markdown]
# # 4. Exporting Merged Cleaned Data Frames

# %%
# Export df_ords_prods_deps_clean pickle
df_ords_prods_deps_clean.to_pickle(os.path.join('/Users', 'xxx', 'Documents', 'Instacart Basket Analysis - 2025-01-05', '02 - Data','Prepared Data', 'ords_prods_deps_cleaned.pkl'))

# %%
# Export df_ords_prods_deps_clean csv
df_ords_prods_deps_clean.to_csv(os.path.join('/Users', 'xxx', 'Documents', 'Instacart Basket Analysis - 2025-01-05', '02 - Data','Prepared Data', 'ords_prods_deps_cleaned.csv'))
